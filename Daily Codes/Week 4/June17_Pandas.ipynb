# %%
import numpy as np

# %%
a = np.array([12,33.5,True,'aryan'])

# %%
a
# Out:
# array(['12', '33.5', 'True', 'aryan'], dtype='<U32')

# %%
# pandas dataframe

# %%
# Dataframe : manually

# %%
import pandas as pd

# %%
roll = pd.Series([1,2,3,4,5])
name = pd.Series(['sia','ravi','geet','ajeenkya','avinash'])
marks = pd.Series([85,67,59,40,90])

# %%
df = pd.DataFrame({
    'id':roll,
    'name':name,
    'marks':marks
})

# %%
df
# Out:
#    id      name  marks
# 0   1       sia     85
# 1   2      ravi     67
# 2   3      geet     59
# 3   4  ajeenkya     40
# 4   5   avinash     90

# %%
df.ndim
# Out:
# 2

# %%
df.shape
# Out:
# (5, 3)

# %%
df.size
# Out:
# 15

# %%
df.columns
# Out:
# Index(['id', 'name', 'marks'], dtype='object')

# %%
pwd
# Out:
# 'C:\\Users\\Tajeswini\\internship 26'

# %%
# Dataframe : via datasets

# %%
df = pd.read_csv("student.csv")

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
col = ['roll','name','class','marks']

# %%
df1 = pd.read_csv("student1.csv" , names = col)

# %%
df1
# Out:
#        roll name  class  marks
# 1      anil   TE  56.77     22
# 2      amit   TE  59.77     21
# 3    aniket   BE  76.88     19
# 4   ajinkya   TE  69.66     20
# 5      asha   TE  63.28     20
# 6    ayesha   BE  49.55     20
# 7      amar   BE  65.34     19
# 8     amita   BE  68.33     23
# 9      amol   TE  56.75     20
# 10    anmol   BE  78.66     21

# %%
df3 = pd.read_csv("student3.tsv" , sep = '\t')

# %%
df3
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21
