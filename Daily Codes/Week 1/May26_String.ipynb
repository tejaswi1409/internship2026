# %% [markdown]
# ## string function

# %%
name = "Nitesh"

# %%
name.lower()
# Out:
# 'nitesh'

# %%
name
# Out:
# 'Nitesh'

# %%
name = name.lower()

# %%
name
# Out:
# 'nitesh'

# %%
name.upper()
# Out:
# 'NITESH'

# %%
name.title()
# Out:
# 'Nitesh'

# %%
name.swapcase()
# Out:
# 'NITESH'

# %%
name = "Nitesh"

# %%
name.swapcase()
# Out:
# 'nITESH'

# %%
name.isupper()
# Out:
# False

# %%
name.islower()
# Out:
# False

# %%
name.istitle()
# Out:
# True

# %%
name1 = "ok"
name2 = "123"
name3 = "ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name3.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name3.isdigit()
# Out:
# False

# %%
name3.isalnum()
# Out:
# True

# %%
name1.isalpha()
# Out:
# True

# %%
name = "Pune"

# %%
print(name)
# Out:
# Pune

# %%
name.startswith("P")
# Out:
# True

# %%
name.endswith("Pune")
# Out:
# True

# %%
name.endswith("e")
# Out:
# True

# %%
name = " Pune "

# %%
name.lstrip()
# Out:
# 'Pune '

# %%
name.rstrip()
# Out:
# ' Pune'

# %%
name.strip()
# Out:
# 'Pune'

# %%
len(name)
# Out:
# 6

# %%
name.replace('u', 'oo')
# Out:
# ' Poone '

# %% [markdown]
# ## operators

# %%
# arithmatic

# %%
a = 5
b = 10

# %%
a+b
# Out:
# 15

# %%
a - b
# Out:
# -5

# %%
a * b
# Out:
# 50

# %%
a / b
# Out:
# 0.5

# %%
a ** b #raise to op
# Out:
# 9765625

# %%
a % b
# Out:
# 5

# %%
b % a
# Out:
# 0

# %%
a // b
# Out:
# 0

# %%
# assignment

# %%
z = 5

# %%
z
# Out:
# 5

# %%
z = z+3
z
# Out:
# 8

# %%
z += 3
z
# Out:
# 11

# %%
z = 5

# %%
z -=1

# %%
z
# Out:
# 4

# %%
z *= 5

# %%
z
# Out:
# 20

# %%
z /=2
z
# Out:
# 10.0

# %%
z **=3
z
# Out:
# 1000.0

# %%
z //=4
z
# Out:
# 250.0

# %%
# comparison

# %%
a = 10 
b = 15

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >=b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# logical

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %%
# identity operator - is and is not

# %%
a = 5 
b = 5

# %%
id(a), id(b)
# Out:
# (140721974387752, 140721974387752)

# %%
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
a = [3,4]
b = [3,4]

# %%
a is b
# Out:
# False

# %%
id(a) , id(b)
# Out:
# (2823340410432, 2823340819200)

# %%
z = a

# %%
a  is z
# Out:
# True

# %%
a.append(10)

# %%
a
# Out:
# [3, 4, 10]

# %%
z
# Out:
# [3, 4, 10]

# %%
# membership seletion operator

# %%
l = [2,5,7,8,]

# %%
2 in l
# Out:
# True

# %%
10 in l
# Out:
# False

# %%
20 not in l
# Out:
# True

# %% [markdown]
# ## precendence and association

# %%
# BODMOS

# %%
5 + 2 - 10
# Out:
# -3

# %%
(4-2) **2
# Out:
# 4

# %%
2 ** 2 ** 3
# Out:
# 256

# %%
2 ** 3 / 2
# Out:
# 4.0

# %%
# print functio

# %%
name = "geeta"
marks = 91.56

# %%
print("my name is ", name ,"and marks are ", marks)
# Out:
# my name is  geeta and marks are  91.56

# %%
print("my name is %s and marks are %i" %(name , marks))
# Out:
# my name is geeta and marks are 91

# %%
print(f"my name is {name} and marks are {marks}") #formated string
# Out:
# my name is geeta and marks are 91.56

# %%
# dir and help

# %%
dir(name)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
help(name.rfind)
# Out:
# Help on built-in function rfind:
#
# rfind(sub[, start[, end]], /) method of builtins.str instance
#     Return the highest index in S where substring sub is found, such that sub is contained within S[start:end].
#
#     Optional arguments start and end are interpreted as in slice notation.
#     Return -1 on failure.

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("A")
# Out:
# 65

# %%
chr(56)
# Out:
# '8'

# %%
chr(97)
# Out:
# 'a'

# %% [markdown]
# ## type casting

# %%
num1 = 34
num2 = 44.56
num3= "ok"

# %%
float(num1)
# Out:
# 34.0

# %%
int(num2)
# Out:
# 44

# %%
str(num1)
# Out:
# '34'

# %%
str(num2)
# Out:
# '44.56'

# %%
int(num3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[130], line 1
# ----> 1 int(num3)
#
# ValueError: invalid literal for int() with base 10: 'ok'

# %% [markdown]
# ## user input

# %%
a = input("enter the number:")
# Out:
# enter the number: 20

# %%
b = input("enter the number 2:")
# Out:
# enter the number 2: 10

# %%
a + b
# Out:
# '2010'

# %%
c = int(input("enter no 1"))
d = int(input("enter no 2"))
d= c+d
print(d)
# Out:
# enter no 1 20
# enter no 2 30
# 50

# %%
time = int(input("enter the time in seconds :"))
hour = time // 3600
minute = (time % 3600) // 60 
seconds = time % 3600
print("")
