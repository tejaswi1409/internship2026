# %%
print("teja")
# Out:
# teja

# %%
num = 20

# %%
num
# Out:
# 20

# %%
no = 24

no2 = 20.3

name = 30

# %%
type(no)
# Out:
# int

# %%
type(no2)
# Out:
# float

# %%
name = "teja"

# %%
type(name)
# Out:
# str

# %%
num2 = 23e4

# %%
num2
# Out:
# 230000.0

# %%
sent = " i want to learn python "

# %%
print(sent)
# Out:
#  i want to learn python

# %%
# i want to learn "python"
# i want to learn 'python'

# %%
sent2 = "i want to learn 'python' "

# %%
print(sent2)
# Out:
# i want to learn 'python'

# %%
sent3 = 'i want to learn "python" '

# %%
print(sent3)
# Out:
# i want to learn "python"

# %%
num = 3 
if num > 0 :
    print("greater")
else :
    print("lower")
# Out:
# greater

# %%
num1 = 20 
num2 = 40 
print( "sum =" , num1 + num2)
# Out:
# sum = 60

# %%
a = 20 ; b = 10 ; c = a+b ; print(c)
# Out:
# 30

# %%
a, b, c, = 35, 56, "fine"

# %%
a
# Out:
# 35

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'fine'
