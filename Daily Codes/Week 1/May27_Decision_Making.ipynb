# %% [markdown]
# ## if elif else

# %%
num = int (input("enter the number:"))

if num > 5:
    print('yes')
# Out:
# enter the number: 6
# yes

# %%
num = int (input("enter the number"))

if num> 5:
    print('yes')
else:
    print('no')
# Out:
# enter the number 4
# no

# %%
num = int(input("enter the number"))

if num > 0:
    print('positive')
else:
    print('negative')
# Out:
# enter the number -2
# negative

# %%
num = int(input("enter the number"))

if num > 0:
    print('positive')
elif num == 0:
    print('zero')
else:
    print('negative')
# Out:
# enter the number 0
# zero

# %%
num = int(input("entr the number"))

if num % 2 == 0:
    print("even")
else:
    print("odd")
# Out:
# entr the number 4
# even

# %%
int(True)
# Out:
# 1

# %%
int (False)
# Out:
# 0

# %%
True + True + False
# Out:
# 2

# %%
a = 1
if a:
    print('exists')
# Out:
# exists

# %%
num = int(input("enter the number"))

if num >= 50:
    if num <= 100:
        print("number is between 50 and 100")
    else :
        print("number is not between")
else :
    print("number is less than 50")
# Out:
# enter the number 50
# number is between 50 and 100

# %%
num = int(input("enter the number"))

if num > 50 and num <100:
    print("number is between 50 and 100")
else:
    print("number is not between 50 and 100")
# Out:
# enter the number 56
# number is between 50 and 100

# %%
purchase_cost = int(input("enter the purchase cost"))
selling_cost = int(input("enter the selling cost "))

if purchase_cost > selling_cost :
    print("it is loss and loss is " , purchase_cost - selling_cost )
else :
    print("it is profit and profit is" , selling_cost- purchase_cost )
# Out:
# enter the purchase cost 4000
# enter the selling cost  2000
# it is loss and loss is  2000

# %%
year = int(input("enter the year "))

if year % 4 == 0:
   if year % 400 == 0 :
        print("this is century leap year ")
   else : 
        print("this in not cetury leap year")
else:
    print("year is  not leap")
# Out:
# enter the year  2005
# year is  not leap

# %%
y = int(input("enter the year "))

if y % 4==0:
    if y % 100 ==0:
        if y % 400 ==0:
            print("century leap")
        else:
            print("century but not leap ")
    else:
        print("leap yaer")
else:
    print("not leap year")
# Out:
# enter the year  1800
# century but not leap

# %%
num1 = int(input("enter the number 1"))
num2 = int(input("enter the number 2"))
num3 = int(input("enter the number 3"))

if num1 > num2:
    if num1 > num3:
        print("number 1 is larger")
    else:
        print("number 3 is larger")
else:
    if num2 > num3:
            print("number 2 is larger")
    else :
        print("number 3 is larger")
# Out:
# enter the number 1 4
# enter the number 2 6
# enter the number 3 70
# number 3 is larger

# %%
print("welcome to simple calculator")

num = int(input("enter the number"))

print("Menu = \n1. Square \n2. Cube \n2. check +ve or -ve")

ch = int(input("enter the choice"))

if ch == 1:
    print("Square:", num * num)
elif ch == 2:
    print("Cube:",num * num * num)
elif ch == 3 :
    if num > 0:
        print("positive")
    elif num == 0:
        print("zero")
    else :
        print("negative")
else:
    print("invalid choice")
# Out:
# welcome to simple calculator
# enter the number 30
# Menu =
# 1. Square
# 2. Cube
# 2. check +ve or -ve
# enter the choice 2
# Cube: 27000

# %%
string = input("enter the string")

print("Menu => \n1.upper \n2. lower \n3. replace")
ch= int(input("enter the choice"))
if ch == 1:
    print(string.upper())
elif ch == 2:
    print(string.lower())
elif ch == 3:
    print("replace a perticular ch of string")
    r = input("char to replaced ")
    b = input("char to replace by")
    print(string.replace(r,b))
else :
    print("invalid choice")
# Out:
# enter the string raj
# Menu =>
# 1.upper
# 2. lower
# 3. replace
# enter the choice 3
# replace a perticular ch of string
# char to replaced  r
# char to replace by s
# saj
