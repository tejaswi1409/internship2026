# %% [markdown]
# ## List

# %%
l = [23,45,67,89,12]

# %%
print(l)
# Out:
# [23, 45, 67, 89, 12]

# %%
# list are hetero and duplicates are allowed

l = [24 , 53 , 45 , 67.90 , 89 ,"python" , "java", 23, 53 ]

# %%
print(l)
# Out:
# [24, 53, 45, 67.9, 89, 'python', 'java', 23, 53]

# %%
# list are ordered

# %%
l
# Out:
# [24, 53, 45, 67.9, 89, 'python', 'java', 23, 53]

# %%
l[2]
# Out:
# 45

# %%
l[0]
# Out:
# 24

# %%
l[-3]
# Out:
# 'java'

# %%
l[-1]
# Out:
# 53

# %%
# list are mutable

# %%
l[2] = 100

# %%
print(l)
# Out:
# [24, 53, 100, 67.9, 89, 'python', 'java', 23, 53]

# %%
l[-3] = True

# %%
print(l)
# Out:
# [24, 53, 100, 67.9, 89, 'python', True, 23, 53]

# %%
# list slicing

# %%
l1 = [21 , 23 , 45 , 67 , 89, 90 ]

# %%
l1
# Out:
# [21, 23, 45, 67, 89, 90]

# %%
l1[1:4]
# Out:
# [23, 45, 67]

# %%
l1[1:-2]
# Out:
# [23, 45, 67]

# %%
l1[0:5:2]
# Out:
# [21, 45, 89]

# %%
l1[::2]
# Out:
# [21, 45, 89]

# %%
# list reverse

# %%
l1[::-1]
# Out:
# [90, 89, 67, 45, 23, 21]

# %%
l1[1:4] = [100, 200 , 300]

# %%
l1
# Out:
# [21, 100, 200, 300, 89, 90]

# %%
l2 = [12, 34, 56 ,23]

# %%
del l2[-2]

# %%
l2
# Out:
# [12, 34, 23]

# %%
l = [12, 34, 56 ,23]

# %%
12 in l
# Out:
# True

# %%
1099 in l
# Out:
# False

# %%
l1
# Out:
# [21, 100, 200, 300, 89, 90]

# %%
'ok' * 3 # string repittion
# Out:
# 'okokok'

# %%
l1 * 2 # list repitation
# Out:
# [21, 100, 200, 300, 89, 90, 21, 100, 200, 300, 89, 90]

# %%
l1 + [20,30,40] # concatiation of list
# Out:
# [21, 100, 200, 300, 89, 90, 20, 30, 40]

# %%
# 2 list addition

# %%
l1 = [12, 23, 45,67, 78]

# %%
l2 = [34, 67, 87, 98,34]

# %%
l1 + l2
# Out:
# [12, 23, 45, 67, 78, 34, 67, 87, 98, 34]

# %%
# iteration on list

# %%
list = [12, 23, 45, 67, 78]
for i in list:
    print(i* i)
# Out:
# 144
# 529
# 2025
# 4489
# 6084

# %%
list = [12, 23, 45, 67, 78]
for i in list:
    if i % 2 != 0:
        print(i)
# Out:
# 23
# 45
# 67

# %%
# list comprehesion -> [expression for_loop if condiotion]

# %%
new = [i*i for i in list]

# %%
new
# Out:
# [144, 529, 2025, 4489, 6084]

# %%
new2 = [i for i in list if i % 2!=0]

# %%
new2
# Out:
# [23, 45, 67]

# %%
names = ["Aryan" ,"atharv", "sammruddhi", "swaraj", "Suknya", "shivraj"]

# %%
new3 = [i for i in names if i.startswith(('s' ,'S'))]

# %%
new3
# Out:
# ['sammruddhi', 'swaraj', 'Suknya', 'shivraj']

# %%
new4 = [i for i in names if i.lower().startswith('s')]

new4
# Out:
# ['sammruddhi', 'swaraj', 'Suknya', 'shivraj']

# %%
new5 = [i for i in names if i[0]== 's' or i[0]== 'S']

new5
# Out:
# ['sammruddhi', 'swaraj', 'Suknya', 'shivraj']

# %%
# functions

# %%
l
# Out:
# [12, 34, 56, 23]

# %%
len(l)
# Out:
# 4

# %%
max(l)
# Out:
# 56

# %%
min(l)
# Out:
# 12

# %%
sorted(l)
# Out:
# [12, 23, 34, 56]

# %%
sorted(l,reverse = True)
# Out:
# [56, 34, 23, 12]

# %%
#list methods

# %%
# append

l.append(100)

# %%
l
# Out:
# [12, 34, 56, 23, 100]

# %%
l1 =[1, 2, 3]
l2 =[1,2,3]

# %%
l1.append([100 , 200])
l2.extend([100 , 200])

# %%
l1
# Out:
# [1, 2, 3, [100, 200]]

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l1[3]
# Out:
# [100, 200]

# %%
l1[3][1]
# Out:
# 200

# %%
l1[3][1] = 300

# %%
l1
# Out:
# [1, 2, 3, [100, 300]]

# %%
# insert

# %%
l
# Out:
# [12, 34, 56, 23, 100]

# %%
l.insert(1, 17)

# %%
l
# Out:
# [12, 17, 34, 56, 23, 100]

# %%
# remove -> when index is not known

# %%
l.remove(23)

# %%
l
# Out:
# [12]

# %%
# pop ->

# %%
l.pop(1)
# Out:
# 56

# %%
l
# Out:
# [12, 56, 23]

# %%
l.index(12)
# Out:
# 0

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l2.sort()

# %%
l2
# Out:
# [1, 2, 3, 100, 200]

# %%
l2.sort(reverse= True)

# %%
l2
# Out:
# [200, 100, 3, 2, 1]

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']
