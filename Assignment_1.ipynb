# %% [markdown]
# ## ASSIGNMENT 1

# %% [markdown]
# 1. Take two numbers as input from the user and print their sum, difference, product, and
#    quotient — each on a separate line. Handle division by zero with an appropriate message

# %%
num1 = int(input("enter the number 1 : "))
num2 = int(input("enter the number 2 : "))
# Out:
# enter the number 1 :  30
# enter the number 2 :  12

# %%
sum = num1 + num2 

print("Addition :",sum)
# Out:
# Addition : 42

# %%
diff = num1 - num2 

print("subtraction :",diff)
# Out:
# subtraction : 18

# %%
pro = num1 * num2

print("product :", pro)
# Out:
# product : 360

# %%
div = num1 / num2 

print("quotient :",div)
# Out:
# quotient : 2.5

# %%
num1 = int(input("enter the number 1 : "))
num2 = int(input("enter the number 2 : "))
# Out:
# enter the number 1 :  30
# enter the number 2 :  0

# %%
if num2 == 0:
    print("cannot divide by zero ")
else :
    div0 = num1 / num2 
    print("Division :" , div0)
# Out:
# cannot divide by zero

# %% [markdown]
# 2. Accept a temperature in Celsius from the user, convert it to Fahrenheit and Kelvin, and
# print all three values with labels.

# %%
temp = int(input("enter the temprature in celsius :"))
# Out:
# enter the temprature in celsius : 30

# %%
farh = (9/ 5) * temp + 32
print(f" celsius to fahrenheit :{farh} F")

kel = temp  + 273.15
print(f" celsius to kelvin : {kel} K")
# Out:
#  celsius to fahrenheit :86.0 F
#  celsius to kelvin : 303.15 K

# %% [markdown]
# 3. Take a string as input and print: its uppercase version, its length, and the string
# reversed.

# %%
name = input("Enter the string : ")
# Out:
# Enter the string :  java

# %%
print("uppercase :", name.upper())
# Out:
# uppercase : JAVA

# %%
print("Length of string :", len(name))
# Out:
# Length of string : 4

# %%
print("reverse : ", name[::-1])
# Out:
# reverse :  avaj

# %% [markdown]
# 4. Take three numbers as input and print the largest among them. Do not use the built-in
# max() function.

# %%
num1 = int(input("Enter the number 1 : "))
num2 = int(input("Enter the number 2 : "))
num3 = int(input("Enter the number 3 : "))
# Out:
# Enter the number 1 :  13
# Enter the number 2 :  56
# Enter the number 3 :  45

# %%
if num1 > num2 :
    if num1 > num3 :
        print(f" number 1 that is {num1} is largest number ")
    else:
        print(f"number 3 that is {num3} is largest number ")
elif  num2 > num3:
    print(f"number 2 that is {num2 } is largest number ")
else :
    print(f" number 3 that is {num3 } is largest number ")
# Out:
# number 2 that is 56 is largest number

# %% [markdown]
# 5. Take a year as input and print whether it is a leap year or not

# %%
year = int(input("enter the year :"))
# Out:
# enter the year : 1800

# %%
if year % 4 ==0 :
    if year % 10 == 0 :
        if year % 400 == 0:
             print(f"{year} is leap year but century leap year")
        else :
            print(f"{year} is century year but not leap year" )
    else :
        print(f"{year} is leap year ")
else :
    print(f"{year} is not a leap year ")
# Out:
# 1800 is century year but not leap year

# %% [markdown]
# 6. Build a simple calculator — take two numbers and an operator (+, -, *, /) as input,
# perform the operation, and print the result. Print an error message for invalid operators or
# division by zero

# %%
num1 = int(input("Enter the number 1 :"))
num2 = int(input("Enter the number 2 :"))

print("1 . + operator   \n2 . - operator  \n3 . * operator \n4 . / operator  " )

ch =int(input("Enter the operator  :"))
if ch == 1:
    print("Addition : ", num1 + num2 )
    
elif ch == 2 :
    print("Subtraction : ", num1 - num2 )
    
elif ch == 3:
    print("Multiplication : ", num1 * num2 )
    
elif ch == 4: 
    if num2 == 0 :
        print("cannot be divide by zero ")
    else :
        print("Division : ", num1 / num2 )
    
else :
    print("Invalid operator ")
# Out:
# Enter the number 1 : 30
# Enter the number 2 : 21
# 1 . + operator
# 2 . - operator
# 3 . * operator
# 4 . / operator
# Enter the operator  : 2
# Subtraction :  9

# %% [markdown]
# 7. Take a number as input and print its multiplication table from 1 to 10. Format each line
# as: 7 x 3 = 21

# %%
num = int(input("Enter the number :"))

for i in range (1,11):
    print( f" {num} * {i} = {num*i}")
# Out:
# Enter the number : 3
#  3 * 1 = 3
#  3 * 2 = 6
#  3 * 3 = 9
#  3 * 4 = 12
#  3 * 5 = 15
#  3 * 6 = 18
#  3 * 7 = 21
#  3 * 8 = 24
#  3 * 9 = 27
#  3 * 10 = 30

# %% [markdown]
# 8. Take a positive integer n as input and print all prime numbers from 2 to n

# %%
n = int(input("Enter the number :"))
for i in range(2 ,n):
    c = 0
    for j in range(2, i):
        if i % j == 0:
            c= 1
            break 
    if c==0 :
        print(i)
# Out:
# Enter the number : 20
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19

# %% [markdown]
# 9. Keep accepting numbers from the user until they enter 0. Then print the total count of
# numbers entered, their sum, and their average. Do not include 0 in the calculations.

# %%
nums = int(input("Enter the numbers until enter 0 "))

count = 0
sum = 0

while nums != 0 :
    sum = sum + nums
    count = count +1
    nums = int(input("Enter the numbers until enter 0 : "))
    
print("sum of numbers :" , sum)
print("count of numbers : ", count)

if count > 0 :
    print("Average :" , sum / count)
# Out:
# Enter the numbers until enter 0  56
# Enter the numbers until enter 0 :  54
# Enter the numbers until enter 0 :  33
# Enter the numbers until enter 0 :  23
# Enter the numbers until enter 0 :  54
# Enter the numbers until enter 0 :  0
# sum of numbers : 220
# count of numbers :  5
# Average : 44.0

# %% [markdown]
# 10. Take n as input and print a triangle pattern of n rows made of asterisks, where row i
# has (2i - 1) stars centered appropriately

# %%
n = int(input("Enter number of input : "))

for i in range(1, n + 1):
    # Print spaces
    print(" " * (n - i), end="")
    
    # Print stars
    print("*" * (2 * i - 1))
# Out:
# Enter number of input :  6
#      *
#     ***
#    *****
#   *******
#  *********
# ***********
